# %%
import sys
# Inserting the path of our taks/modules folder.
sys.path.insert(0, "/home/jovyan/my_notebooks/Python_Exam/Task")
import task_1,task_2,task_3,task_4,task_5,task_6

print('\n /-----\ Task One! /-----\ \n')
task_1.run()

print('\n /-----\ Task Two! /-----\ \n')
task_2.run()

print('\n /-----\ Task Three! /-----\ \n')
task_3.run()

print('\n /-----\ Task Four! /-----\ \n')
task_4.run()

print('\n /-----\ Task Five! /-----\ \n')
task_5.run()

print('\n /-----\ Task Six! /-----\ \n')
task_6.run()
task_6.run1()
# Out:
#  /-----\ Task One! /-----\
#
# dance pop average beats per minute for the top 5 most popular songs = 113.8
# modern alternative rock average beats per minute for the top 5 most popular songs = 115.2
# acoustic pop average beats per minute for the top 5 most popular songs = 23.8
#
#  /-----\ Task Two! /-----\
#  /-----\ Task Three! /-----\
# [[-1.37244497]]
#
#  /-----\ Task Four! /-----\
#
# Artist type: Duo
# Genres and ratings: {'modern rock': 88.0, 'metropopolis': 87.0, 'pop': 83.0}
# Artist type: Solo
# Genres and ratings: {'chill pop': 94.0, 'dark clubbing': 89.0, 'bedroom pop': 88.0}
# Artist type: Band/Group
# Genres and ratings: {'australian psych': 88.0, 'reggae fusion': 85.0, 'indie pop': 84.0}
# Artist type: Trio
# Genres and ratings: {'atl hip hop': 75.66666666666667, 'modern rock': 71.0, 'dance pop': 70.2}
#
#  /-----\ Task Five! /-----\
#
# artist_Taylor Swift     21
# artist_Calvin Harris    18
# artist_Drake            18
# artist_Ariana Grande    14
# artist_Rihanna          14
# artist_Bruno Mars       12
# artist_Maroon 5         11
# artist_Chris Brown      10
# artist_Jason Derulo     10
# artist_Ed Sheeran       10
# dtype: int64
#
#  /-----\ Task Six! /-----\
#
# {'Sweater Weather': 'The Neighbourhood', 'Another Love': 'Tom Odell', 'Lost': 'Frank Ocean', 'Locked out of Heaven': 'Bruno Mars', 'Believer': 'Imagine Dragons'}
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /opt/conda/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# /opt/conda/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Robert Pallesen\\OneDrive\\Datamatiker\\4. Semester\\Python\\docker_notebooks\\venv\\Lib\\site-packages\\selenium\\webdriver\\chrome\\geckodriver.exe': 'C:\\Users\\Robert Pallesen\\OneDrive\\Datamatiker\\4. Semester\\Python\\docker_notebooks\\venv\\Lib\\site-packages\\selenium\\webdriver\\chrome\\geckodriver.exe'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-7-10fbc3f576af> in <module>
#      20
#      21 print('\n /-----\ Task Six! /-----\ \n')
# ---> 22 task_6.run()
#
# ~/my_notebooks/Python_Exam/Task/task_6.py in run()
#      33     url = 'https://www.azlyrics.com/'
#      34
# ---> 35     # driver setup
#      36     driver = Webscraper.init_webdriver()
#      37
#
# /opt/conda/lib/python3.7/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, options, service_log_path, firefox_options, service_args, desired_capabilities, log_path, keep_alive)
#     162                 service_args=service_args,
#     163                 log_path=service_log_path)
# --> 164             self.service.start()
#     165
#     166             capabilities.update(options.to_capabilities())
#
# /opt/conda/lib/python3.7/site-packages/selenium/webdriver/common/service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'C:\Users\Robert Pallesen\OneDrive\Datamatiker\4. Semester\Python\docker_notebooks\venv\Lib\site-packages\selenium\webdriver\chrome\geckodriver.exe' executable needs to be in PATH.
